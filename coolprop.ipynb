# %% [markdown]
# <a href="https://colab.research.google.com/github/Kovtun01-22/lab-2/blob/main/coolprop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Система уравнений

# %%
import numpy as np 
from scipy.optimize import fsolve 
def f(p): 
  x,y=p
  return (x**2+y*x-10,x*y+y**2+np.sin(x)+7)
x,y= fsolve(f,(1,3))
print(x,y)
# Out:
# 5.031943969582944 -3.04464044227471

# %% [markdown]
# фунцкия coolproop

# %%
pip install CoolProp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import CoolProp.CoolProp as ct 
import matplotlib.pyplot as plt
t=np.linspace(283.15,400,500)
p=101325 
d=ct.PropsSI("D","T",t,"P",p,"water")
print(d)
plt.plot(t,d)
plt.title("график")
plt.xlabel("tK")
plt.ylabel("pP")
plt.scatter(373.15,958,color="red")
plt.grid()
plt.show()
# Out:
# [9.99702470e+02 9.99681519e+02 9.99659838e+02 9.99637432e+02
#  9.99614305e+02 9.99590462e+02 9.99565908e+02 9.99540646e+02
#  9.99514681e+02 9.99488017e+02 9.99460659e+02 9.99432609e+02
#  9.99403874e+02 9.99374455e+02 9.99344359e+02 9.99313587e+02
#  9.99282145e+02 9.99250037e+02 9.99217265e+02 9.99183834e+02
#  9.99149748e+02 9.99115009e+02 9.99079623e+02 9.99043592e+02
#  9.99006920e+02 9.98969611e+02 9.98931667e+02 9.98893093e+02
#  9.98853892e+02 9.98814067e+02 9.98773622e+02 9.98732559e+02
#  9.98690883e+02 9.98648596e+02 9.98605702e+02 9.98562204e+02
#  9.98518104e+02 9.98473406e+02 9.98428114e+02 9.98382229e+02
#  9.98335756e+02 9.98288697e+02 9.98241054e+02 9.98192832e+02
#  9.98144032e+02 9.98094659e+02 9.98044713e+02 9.97994199e+02
#  9.97943119e+02 9.97891476e+02 9.97839272e+02 9.97786511e+02
#  9.97733194e+02 9.97679325e+02 9.97624906e+02 9.97569940e+02
#  9.97514429e+02 9.97458375e+02 9.97401783e+02 9.97344652e+02
# ...
